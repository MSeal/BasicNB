# %% [markdown]
# # Test

# %%
import numpy as np
a = 1
x = np.arange(0, 5, 1)

# %%
import matplotlib.pyplot as plt
plt.plot(x, x)

# %% [markdown]
# # Test 2

# %% [markdown]
# ## Test 3

# %% [markdown]
# ### Another level

# %%
plt.plot(x, 2*x**2)
